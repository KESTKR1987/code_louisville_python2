# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

# %%
Energy = pd.read_excel('Energy Indicators.xls', header=None, footer=None, usecols='C:G')
Energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
Energy["Energy Supply"] = 1000000 * Energy["Energy Supply"]
Energy = Energy.dropna()
Energy['Country'] = Energy['Country'].replace(["Republic of Korea","United States of America",
                                               "China, Hong Kong Special Administrative Region",
                                              "United Kingdom of Great Britain and Northern Ireland",
                                              "Switzerland17","Bolivia (Plurinational State of)"],
                                              ["South Korea","United States","United Kingdom","Hong Kong","Switzerland",
                                              "Bolivia"])
Energy = Energy.replace('...', np.NaN)
Energy.drop([9, 11], axis=0).head(50)
# Out:
#                                             Country  \
# 18                                      Afghanistan
# 19                                          Albania
# 20                                          Algeria
# 21                                   American Samoa
# 22                                          Andorra
# 23                                           Angola
# 24                                         Anguilla
# 25                              Antigua and Barbuda
# 26                                        Argentina
# 27                                          Armenia
# 28                                            Aruba
# 29                                       Australia1
# 30                                          Austria
# 31                                       Azerbaijan
# 32                                          Bahamas
# 33                                          Bahrain
# 34                                       Bangladesh
# ...

# %%
GDP = pd.read_csv('world_bank.csv', header=None)
GDP.replace(["Korea, Rep.","Iran, Islamic Rep.","Hong Kong SAR, China"],
                            ["South Korea","Iran","Hong Kong"])
GDP
# Out:
#                     0                             1   \
# 0          Data Source  World Development Indicators
# 1                  NaN                           NaN
# 2    Last Updated Date                     7/22/2016
# 3                  NaN                           NaN
# 4         Country Name                  Country Code
# ..                 ...                           ...
# 264        Yemen, Rep.                           YEM
# 265       South Africa                           ZAF
# 266   Congo, Dem. Rep.                           COD
# 267             Zambia                           ZMB
# 268           Zimbabwe                           ZWE
#
#                                            2               3             4   \
# 0                                         NaN             NaN           NaN
# 1                                         NaN             NaN           NaN
# 2                                         NaN             NaN           NaN
# ...

# %%
ScimEn = pd.read_excel('scimagojr-3.xlsx')
ScimEn.head(50)
# Out:
#     Rank               Country  Documents  Citable documents  Citations  \
# 0      1                 China     127050             126767     597237
# 1      2         United States      96661              94747     792274
# 2      3                 Japan      30504              30287     223024
# 3      4        United Kingdom      20944              20357     206091
# 4      5    Russian Federation      18534              18301      34266
# 5      6                Canada      17899              17620     215003
# 6      7               Germany      17027              16831     140566
# 7      8                 India      15005              14841     128763
# 8      9                France      13153              12973     130632
# 9     10           South Korea      11983              11923     114675
# 10    11                 Italy      10964              10794     111850
# 11    12                 Spain       9428               9330     123336
# ...

# %%
Energy = Energy.set_index('Country')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-297-7d8de8dffa77> in <module>
# ----> 1 Energy = Energy.set_index('Country')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"
